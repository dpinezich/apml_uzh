# %% [markdown]
# # Chapter 01 — Exercises: Introduction to ML & Data Science Workflows
#
# **Session 1 | Chapter 1 | Bonus exercise (optional, ~10 minutes)**
#
# You will explore the **Palmer Penguins dataset**: inspect its structure,
# plot distributions, and identify missing values — all before fitting any model.
#
# > **Goal:** Practice the first three steps of the DS Workflow:
# > ① Define the problem → ② Inspect the data → ③ Explore & visualize

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
np.random.seed(42)
print('Ready!')

# %% [markdown]
# ## Setup: Load the Penguins Dataset
#
# The **Palmer Penguins** dataset contains measurements of 344 penguins
# from 3 species across 3 islands in Antarctica. Run the cell below — it reads `penguins.csv` from this folder (offline).

# %%
import os

# Load the Palmer Penguins dataset. Preferred: the local CSV shipped with the course (works offline).
# Fallback: seaborn's built-in loader (needs internet the first time).
csv_path = os.path.join('..', '03-exercises', 'penguins.csv') if not os.path.exists('penguins.csv') else 'penguins.csv'
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
else:
    df = sns.load_dataset('penguins')

print('Dataset loaded! Shape:', df.shape)
df.head()

# %% [markdown]
# ---
# ## Task 1: Inspect the Dataset (~2 min)
#
# Before anything else — understand what you're working with.

# %%
# TODO 1a: Print the shape of the dataset (rows, columns)
# How many penguins? How many features?

# %%
# TODO 1b: Print the data types and count of non-null values
# Hint: df.info()

# %%
# TODO 1c: Count missing values per column
# Which columns have missing data? How many rows are complete?

# %%
# TODO 1d: How many penguins of each species are in the dataset?
# Hint: df['species'].value_counts()

# %% [markdown]
# ---
# ## Task 2: Summary Statistics (~2 min)

# %%
# TODO 2: Print the statistical summary of all numerical columns
# Hint: df.describe()
# What is the range of bill_length_mm? Of body_mass_g?

# %% [markdown]
# ---
# ## Task 3: Visualize Feature Distributions (~3 min)

# %%
# TODO 3a: Plot histograms of bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g
# Color each histogram by species (use hue='species')
# Use a 2x2 subplot grid
# Hint: use sns.histplot(data=df, x='col', hue='species', ax=ax, kde=True)

features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Your code here:

plt.suptitle('Feature Distributions by Penguin Species', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# TODO 3b: Create a scatter plot of bill_length_mm vs flipper_length_mm
# Color the points by species
# Does any species look clearly separable?

# %% [markdown]
# ---
# ## Task 4: Connecting to the DS Workflow (~3 min)

# %%
# TODO 4: Compute the mean bill_length_mm per species
# Hint: df.groupby('species')['bill_length_mm'].mean()
# Which species has the longest bill on average?

# %% [markdown]
# ---
# ## Bonus: Pair Plot

# %%
# TODO BONUS: Create a pair plot of all numeric features, colored by species
# Hint: sns.pairplot(df, hue='species', diag_kind='kde')
# Which pair of features best separates the three species?

# %% [markdown]
# ---
#
# **Solutions:** See `../04-solutions/ch01_introduction_solutions.ipynb`
