# %% [markdown]
# # Chapter 05 — Exercises: Classification Models
#
# **Session 2 | Chapter 5 | Core tasks: ~12 minutes, then Bonus**
#
# **Dataset:** `load_wine` — 178 Italian wines, 13 chemical measurements (alcohol, flavanoids, colour intensity, …),
# **3 classes = 3 grape cultivars** (`class_0`, `class_1`, `class_2`). This is a *multi-class* problem — the same
# sklearn calls work, and `classification_report` simply shows one row per class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

sns.set_theme(style='whitegrid')
RANDOM_STATE = 42

wine = load_wine()
X = pd.DataFrame(wine.data, columns=wine.feature_names)
y = wine.target                                    # 0, 1, 2 = three grape cultivars

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y)
print('Shape:', X.shape, '| classes:', wine.target_names.tolist(), '| counts:', np.bincount(y))
print(f'Train: {X_train.shape[0]} | Test: {X_test.shape[0]}')

# %% [markdown]
# ---
# ## Task 1: Baseline + Logistic Regression (~3 min)

# %%
# TODO 1a: Fit DummyClassifier(strategy='most_frequent') and print its test accuracy. This is the number to beat.


# TODO 1b: Pipeline: StandardScaler → LogisticRegression(max_iter=1000). Fit and print test accuracy.
#          Store the fitted pipeline as `lr` (used later).

# %% [markdown]
# ## Task 2: KNN (~2 min)

# %%
# TODO 2: Pipeline: StandardScaler → KNeighborsClassifier(n_neighbors=7). Fit, print test accuracy. Store as `knn`.
#         Why does KNN need the scaler and the Random Forest below does not?

# %% [markdown]
# ## Task 3: Random Forest + classification report (~4 min)

# %%
# TODO 3a: RandomForestClassifier(n_estimators=100, random_state=RANDOM_STATE). Fit, store as `rf`,
#          predictions as y_pred_rf, print test accuracy.


# TODO 3b: print(classification_report(y_test, y_pred_rf, target_names=wine.target_names))
#          Which class has the lowest recall?  (If all are 1.00: the test set is only 36 wines — see Bonus A.)

# %% [markdown]
# ## Task 4: Confusion matrix (~3 min)
# A perfect model gives a boring confusion matrix. So we look at a deliberately *weak* model: a depth-2 tree.

# %%
# TODO 4a: Fit DecisionTreeClassifier(max_depth=2, random_state=RANDOM_STATE) → predictions y_pred_dt.
# TODO 4b: ConfusionMatrixDisplay.from_predictions(y_test, y_pred_dt, display_labels=wine.target_names)
#          Rows = true class, columns = predicted class. Which pair of classes gets confused (off-diagonal cells)?
#          How many wines of class_1 were predicted as class_0?

# %% [markdown]
# ---
# ## Bonus A: 5-fold cross-validation comparison
# 36 test wines is a small sample — one wrong wine changes accuracy by 2.8 %. Cross-validation is more reliable.

# %%
# BONUS A: cross_val_score(model, X, y, cv=5, scoring='accuracy') for lr, knn, rf and
#          DecisionTreeClassifier(max_depth=4, random_state=RANDOM_STATE). Print mean ± std.
#          (For classifiers cv=5 means StratifiedKFold — class ratios preserved in every fold.)
#          Which model is best? Which is most *consistent* (smallest std)?

# %% [markdown]
# ## Bonus B: Support Vector Machine

# %%
# BONUS B: Pipeline: StandardScaler → SVC(kernel='rbf', C=1.0). Add its 5-fold CV accuracy to the comparison.
#          Does it beat the Random Forest?

# %% [markdown]
# ---
#
# **Solutions:** See `../04-solutions/ch05_classification_solutions.ipynb`
