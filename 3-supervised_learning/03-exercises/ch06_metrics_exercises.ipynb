# %% [markdown]
# # Chapter 06 — Exercises: Metrics & Evaluation
#
# **Session 2 | Chapter 6 | Exercise time: ~10 minutes**
#
# You will evaluate models using the right metrics for each scenario.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer, load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_score, recall_score, f1_score, accuracy_score,
    roc_curve, roc_auc_score
)

np.random.seed(42)
print('Ready!')

# %% [markdown]
# ---
# ## Part A: Regression Metrics (~4 min)

# %%
# Setup: diabetes dataset
diabetes = load_diabetes()
X_reg = diabetes.data
y_reg = diabetes.target
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42)

# Train two models
lr = Pipeline([('s', StandardScaler()), ('m', LinearRegression())])
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
lr.fit(X_reg_train, y_reg_train)
rf_reg.fit(X_reg_train, y_reg_train)

y_pred_lr = lr.predict(X_reg_test)
y_pred_rf = rf_reg.predict(X_reg_test)

print('Models trained!')

# %%
# TODO A1: For both models, compute and print: MAE, RMSE, R²
# Which model is better? How do you know?

# %%
# TODO A2: For the BETTER model, create a residual plot
# (x-axis: predicted values, y-axis: residuals = actual - predicted)
# Add a horizontal line at y=0
# Do the residuals look random? Or is there a pattern?

# %% [markdown]
# ---
# ## Part B: Classification Metrics (~6 min)

# %%
# Setup: breast cancer dataset (imbalanced-ish: 37% malignant, 63% benign)
cancer = load_breast_cancer()
X_clf = cancer.data
y_clf = cancer.target  # 0=malignant, 1=benign
X_clf_train, X_clf_test, y_clf_train, y_clf_test = train_test_split(
    X_clf, y_clf, test_size=0.2, random_state=42, stratify=y_clf)

clf = Pipeline([('s', StandardScaler()), ('m', LogisticRegression(max_iter=1000))])
clf.fit(X_clf_train, y_clf_train)

y_clf_pred  = clf.predict(X_clf_test)
y_clf_proba = clf.predict_proba(X_clf_test)[:, 1]

print('Classifier trained!')

# %%
# TODO B1: Compute and print: accuracy, precision, recall, F1
# Which metric is most important for cancer detection? Why?

# %%
# TODO B2: Create and display a confusion matrix
# Identify the number of False Negatives (missed cancer cases)

# %%
# TODO B3: Plot the ROC curve and compute the AUC score
# Use y_clf_proba (the predicted probabilities)

# %%
# TODO B4: What happens if you change the decision threshold from 0.5 to 0.3?
# Recompute recall and precision with threshold=0.3
# Hint: y_pred_custom = (y_clf_proba > 0.3).astype(int)
# Does recall go up? Does precision go down?
# Which threshold would you choose for cancer detection — and why?

# %% [markdown]
# ---
#
# **Solutions:** See `../04-solutions/ch06_metrics_solutions.ipynb`
