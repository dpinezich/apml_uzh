# %% [markdown]
# # Chapter 04 — Exercises: Regression Models
#
# **Session 2 | Chapter 4 | Core tasks: ~10 minutes, then Bonus**
#
# You will predict **diabetes progression** (a medical dataset built into sklearn, 442 patients, 10 features)
# with several regression models and compare them.
#
# Use the `score()` helper defined in the setup cell — you don't have to type the metric code.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

sns.set_theme(style='whitegrid')
RANDOM_STATE = 42

diabetes = load_diabetes()
X = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
y = diabetes.target            # disease progression one year later (higher = worse)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

def score(name, y_true, y_pred):
    '''Helper: print MAE, RMSE, R² in one line.'''
    print(f'{name:<24} MAE={mean_absolute_error(y_true, y_pred):6.2f}  '
          f'RMSE={root_mean_squared_error(y_true, y_pred):6.2f}  R²={r2_score(y_true, y_pred):.3f}')

print('Shape:', X.shape, '| Train:', X_train.shape[0], '| Test:', X_test.shape[0])
print('Features:', list(diabetes.feature_names))

# %% [markdown]
# ---
# ## Task 1: Baseline and Linear Regression (~3 min)

# %%
# TODO 1a: Fit a DummyRegressor (strategy='mean') on the training data and score() it on the test set.
#          This is the number every real model must beat.


# TODO 1b: Build a Pipeline: StandardScaler → LinearRegression. Fit, predict on X_test, score() it.
#          Store the predictions in y_pred_lr (needed for the bonus).

# %% [markdown]
# ## Task 2: Ridge vs Lasso (~3 min)

# %%
# TODO 2: Same pipeline idea for Ridge(alpha=1.0) and Lasso(alpha=1.0). score() both.
#         Then print the Lasso coefficients (pipe.named_steps['model'].coef_) — which features became exactly 0?

# %% [markdown]
# ## Task 3: Random Forest (~4 min)

# %%
# TODO 3a: Train RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE) — no scaler needed. score() it.
#          Store predictions in y_pred_rf.


# TODO 3b: Plot rf.feature_importances_ as a horizontal bar chart (pd.Series(..., index=diabetes.feature_names)).
#          Which feature matters most?  Does the linear model agree (compare with its largest |coefficient|)?

# %% [markdown]
# ---
# ## Bonus A: Cross-validation comparison
# A single split is one random draw. Compare all models with 5-fold CV instead.

# %%
# BONUS A: Use cross_val_score(model, X, y, cv=KFold(5, shuffle=True, random_state=RANDOM_STATE), scoring='r2')
#          for baseline, linear, ridge, lasso, random forest. Print mean ± std for each.
#          Which model wins? Is the difference larger than the std?

# %% [markdown]
# ## Bonus B: Let cross-validation choose alpha

# %%
# BONUS B: Pipeline: StandardScaler → RidgeCV(alphas=np.logspace(-3, 3, 30)). Fit and print .alpha_ (the chosen alpha)
#          and the test-set score(). Is it better than alpha=1.0 from Task 2?

# %% [markdown]
# ## Bonus C: Predicted vs actual plot

# %%
# BONUS C: Scatter y_test (x-axis) vs y_pred_lr and y_pred_rf (y-axis), add a red dashed diagonal.
#          Where does the model struggle — low or high progression values?

# %% [markdown]
# ---
#
# **Solutions:** See `../04-solutions/ch04_regression_solutions.ipynb`
