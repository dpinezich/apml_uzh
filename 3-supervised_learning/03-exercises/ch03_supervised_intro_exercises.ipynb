# %% [markdown]
# # Chapter 03 — Exercises: Introduction to Supervised Learning
#
# **Session 1 | Chapter 3 | Exercise time: ~10 minutes**
#
# You will train your first sklearn model, evaluate it, and observe overfitting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

sns.set_theme(style='whitegrid')
np.random.seed(42)
print('Ready!')

# %% [markdown]
# ## Setup: Load the Iris Dataset

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

print('X shape:', X.shape)
print('Classes:', iris.target_names)
X.head()

# %% [markdown]
# ---
# ## Task 1: Train/Test Split (~2 min)

# %%
# TODO 1: Split X and y into train (80%) and test (20%) sets
# Use random_state=42 and stratify=y

# X_train, X_test, y_train, y_test = ...

print('Train size:', X_train.shape[0])
print('Test size:', X_test.shape[0])

# %% [markdown]
# ## Task 2: Train a KNN Classifier (~3 min)

# %%
# TODO 2a: Create a KNeighborsClassifier with n_neighbors=5

# model = ...

# TODO 2b: Train (fit) the model on the training data


# TODO 2c: Predict on the test data

# y_pred = ...

# TODO 2d: Compute and print the accuracy on the test set

# acc = ...
# print('Test accuracy:', acc)

# %% [markdown]
# ## Task 3: Observe Overfitting (~3 min)
#
# Try different values of k (n_neighbors). For k=1, the model memorizes training data perfectly.

# %%
# TODO 3: For each k in [1, 3, 5, 7, 10, 20]:
#   - Train a KNeighborsClassifier with that k
#   - Compute BOTH training accuracy and test accuracy
#   - Store the results
#   - Print: k, train_acc, test_acc

k_values = [1, 3, 5, 7, 10, 20]

# Your code here:

# %% [markdown]
# ## Task 4: Cross-Validation (~2 min)

# %%
# TODO 4: Use 5-fold cross-validation to find the best k among [1, 3, 5, 7, 10, 20]
# Hint: use cross_val_score(model, X, y, cv=5)
# Print the mean accuracy for each k

# %% [markdown]
# ## Bonus: Train vs Test Accuracy Plot

# %%
# TODO BONUS: Plot train accuracy and test accuracy vs k on the same figure
# Hint: re-run the loop from Task 3 to get train_accs and test_accs,
#       and re-run Task 4's loop to get cv_means — then plot all three on one chart.
# What happens at k=1? At large k?

k_values = [1, 3, 5, 7, 10, 20]

# Collect train/test/cv accuracies for each k
train_accs, test_accs, cv_means = [], [], []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_accs.append(accuracy_score(y_train, knn.predict(X_train)))
    test_accs.append(accuracy_score(y_test,  knn.predict(X_test)))
    cv_means.append(cross_val_score(KNeighborsClassifier(n_neighbors=k), X, y, cv=5).mean())

# Plot
