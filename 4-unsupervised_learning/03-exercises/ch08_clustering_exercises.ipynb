# %% [markdown]
# # Chapter 08 — Exercises: Clustering Techniques
#
# **Session 3 | Chapter 2 | Exercise time: ~10 minutes**
#
# You will cluster the **Iris dataset** (forgetting the species labels) and see
# how well the algorithm recovers the true groups.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, adjusted_rand_score

np.random.seed(42)
print('Ready!')

# %% [markdown]
# ## Setup: Load Data (labels hidden)

# %%
iris = load_iris()
X = iris.data   # 4 features
y_true = iris.target  # we'll use this ONLY at the end to check our work!

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print('Shape:', X.shape)
print('We have 4 features and 150 flowers.')
print('The true labels are hidden — we pretend we don\'t know them!')

# %% [markdown]
# ---
# ## Task 1: Elbow Method (~3 min)

# %%
# TODO 1: Run K-Means for k in range(1, 9)
# Collect inertia for each k
# Plot inertia vs k (the Elbow plot)
# Where is the elbow? Write your answer below.

k_values = range(1, 9)

# Your code here:


# Answer: The elbow appears at k = ___

# %% [markdown]
# ## Task 2: Silhouette Score (~2 min)

# %%
# TODO 2: Compute silhouette scores for k in range(2, 9)
# Print k and its silhouette score
# Which k gives the highest silhouette score?

# %% [markdown]
# ## Task 3: Cluster and Visualize (~3 min)

# %%
# TODO 3: Train K-Means with the k you found from Elbow + Silhouette
# Use the first two features (sepal length and sepal width) for plotting
# Create a scatter plot colored by cluster label
# Add centroids to the plot

# %% [markdown]
# ## Task 4: How Good Were We? (~2 min)
#
# Now we reveal the true labels and compare!

# %%
# TODO 4: Compute the Adjusted Rand Index between your cluster labels and the true labels
# The ARI measures how well the clustering matches the true groups (1.0 = perfect)
# Hint: adjusted_rand_score(y_true, your_labels)


# Also: create a side-by-side plot:
# Left: your cluster assignments
# Right: the true species labels
# How well do they match?

# %% [markdown]
# ## Bonus: DBSCAN

# %%
# TODO BONUS: Apply DBSCAN with eps=0.5, min_samples=5
# How many clusters does it find?
# How many noise points (-1 labels) are there?
# Compare the ARI to K-Means
