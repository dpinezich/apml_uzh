# %% [markdown]
# # Chapter 09 — Exercises: Dimensionality Reduction
#
# **Session 3 | Chapter 9 | Exercise time: ~10 minutes**
#
# You will apply PCA to the breast cancer dataset (30 features)
# and use it for visualization, then as a preprocessing step.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score

sns.set_theme(style='whitegrid')
np.random.seed(42)
print('Ready!')

# %% [markdown]
# ## Setup

# %%
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target  # 0=malignant, 1=benign

print(f'Shape: {X.shape} — {X.shape[1]} features, {X.shape[0]} samples')
print('Task: reduce from 30 to 2 dimensions for visualization')

# %% [markdown]
# ---
# ## Task 1: Scree Plot (~3 min)

# %%
# TODO 1a: Scale the data with StandardScaler
# Hint: ALWAYS scale before PCA!

# X_scaled = ...


# TODO 1b: Fit a full PCA (no n_components limit)
# Plot the cumulative explained variance ratio
# Add horizontal lines at 80%, 90%, 95%
# How many components do you need for each threshold?

# %% [markdown]
# ## Task 2: 2D Visualization (~3 min)

# %%
# TODO 2: Apply PCA with n_components=2 to the scaled data
# Create a scatter plot of PC1 vs PC2
# Color the points by class (malignant=0, benign=1)
# Label the axes with their explained variance percentage
# Are the two classes separated in 2D?

# %% [markdown]
# ## Task 3: PCA as Preprocessing (~4 min)

# %%
# TODO 3a: Build Pipeline 1 (NO PCA):
#   StandardScaler → RandomForestClassifier(n_estimators=100)
# Compute 5-fold CV accuracy



# TODO 3b: Build Pipeline 2 (WITH PCA, keep 95% variance):
#   StandardScaler → PCA(n_components=0.95) → RandomForestClassifier(n_estimators=100)
# Compute 5-fold CV accuracy
# How many components did PCA use? (fit the pipeline on X, check .named_steps['pca'].n_components_)

# %%
# TODO 3c: Print a comparison:
# "Without PCA: X.X% accuracy, 30 features"
# "With PCA 95%: X.X% accuracy, N features"
# Is there a trade-off? Is it worth it?

# %% [markdown]
# ---
# ## Bonus: t-SNE Visualization

# %%
# TODO BONUS: Apply t-SNE to the same breast cancer data and compare to PCA
#
# 1. Apply TSNE(n_components=2, perplexity=30, random_state=42) to X_scaled
#    (use X_scaled from Task 1a — make sure it is defined above)
#
# 2. Create a side-by-side scatter plot: PCA 2D vs t-SNE 2D
#    Color both by class (malignant / benign)
#
# 3. Answer: Are the classes more or less separated in t-SNE vs PCA?
#    Can you trust the distances between points in t-SNE? Why or why not?
#
# Note: t-SNE can be slow on large datasets — this may take ~10 seconds.

# %% [markdown]
# ---
#
# **Solutions:** See `../04-solutions/ch09_dimensionality_reduction_solutions.ipynb`
