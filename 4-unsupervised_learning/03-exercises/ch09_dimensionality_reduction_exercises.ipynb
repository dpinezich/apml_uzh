# %% [markdown]
# # Chapter 09 — Exercises: Dimensionality Reduction
#
# **Session 3 | Chapter 9 | Exercise time: ~10 minutes (Tasks 1–3) · Bonus: t-SNE, loadings**
#
# Breast cancer data (30 features): scree plot → 2-D picture → PCA inside a classifier pipeline vs. baselines.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

sns.set_theme(style='whitegrid')

cancer = load_breast_cancer()
X = cancer.data
y = 1 - cancer.target          # sklearn: 0 = malignant. We FLIP so malignant = 1 = positive class (as in Ch05/06)
feature_names = cancer.feature_names
print(f'{X.shape[0]} tumours × {X.shape[1]} features;  malignant (y=1): {y.sum()}, benign (y=0): {(y == 0).sum()}')
print('Always check which class is the positive one before reading any metric!')

# %% [markdown]
# ---
# ## Task 1: Scree plot (~3 min)

# %%
# TODO 1a: X_scaled = StandardScaler().fit_transform(X)      # always scale before PCA
# TODO 1b: pca_full = PCA().fit(X_scaled); cumvar = np.cumsum(pca_full.explained_variance_ratio_)
#          plot cumvar; PRINT the number of components for 80 %, 90 %, 95 % (np.argmax(cumvar >= t) + 1)

# %% [markdown]
# ## Task 2: 2-D picture (~3 min)

# %%
# TODO 2: pca2 = PCA(n_components=2); X_2d = pca2.fit_transform(X_scaled)
#         scatter PC1 vs PC2, colour by y (malignant=1 red, benign=0 green), axis labels with the % variance.
#         Do the classes separate? How much variance do the 2 PCs keep — and does that matter for the picture?

# %% [markdown]
# ## Task 3: PCA as preprocessing — vs. no PCA vs. dummy (~4 min)

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# TODO 3a: three models, 5-fold CV accuracy each (cross_val_score(model, X, y, cv=cv).mean()):
#   dummy  = DummyClassifier(strategy='most_frequent')
#   rf     = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=100, random_state=42))
#   rf_pca = make_pipeline(StandardScaler(), PCA(n_components=0.95), RandomForestClassifier(n_estimators=100, random_state=42))
# TODO 3b: how many components did PCA keep?  rf_pca.fit(X, y)['pca'].n_components_
# TODO 3c: print a comparison line per model. Is PCA worth it here? (Answer in a comment.)

# %% [markdown]
# ---
# ## Bonus A: t-SNE vs PCA

# %%
# TODO BONUS A: X_tsne = TSNE(n_components=2, perplexity=30, random_state=42).fit_transform(X_scaled)
#   side-by-side scatter (PCA 2-D vs t-SNE), coloured by y.
#   Questions: are the classes more separated in t-SNE? Can you trust distances between the two islands? Why not?
#   Try random_state=1 — does the picture change?

# %% [markdown]
# ## Bonus B: What is PC1 made of?

# %%
# TODO BONUS B: bar plot of pca2.components_[0] with feature_names as x-tick labels.
#   Are the weights concentrated on 1–2 features (→ 'selection') or spread over all 30 (→ 'combination')?

# %% [markdown]
# ---
#
# **Solutions:** `../04-solutions/ch09_dimensionality_reduction_solutions.ipynb`
